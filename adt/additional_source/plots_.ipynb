# %%
# define the filepath
# file_path_133_clean = os.path.join('data', 'results', 'llm_predictions_results_clean_133.csv')
# file_path_137_clean = os.path.join('data', 'results', 'llm_predictions_results_clean_137.csv')
# file_path_142_clean = os.path.join('data', 'results', 'llm_predictions_results_clean_142.csv')
# file_path_150_clean = os.path.join('data', 'results', 'llm_predictions_results_clean_150.csv')
# file_path_131_meal  = os.path.join('data', 'results', 'llm_predictions_results_meal_131.csv')
# file_path_147_meal  = os.path.join('data', 'results', 'llm_predictions_results_meal_147.csv')
# file_path_107_work  = os.path.join('data', 'results', 'llm_predictions_results_work_107.csv')
# file_path_109_work  = os.path.join('data', 'results', 'llm_predictions_results_work_109.csv')
# file_path = os.path.join('data', 'results', 'llm_predictions_results.csv')

# # prints
# print(file_path)
# print(file_path_133_clean)
# print(file_path_137_clean)
# print(file_path_142_clean)
# print(file_path_150_clean)
# print(file_path_131_meal)
# print(file_path_147_meal)
# print(file_path_107_work)
# print(file_path_109_work)
# print(file_path)

# # load the dataframe
# df_133_clean = pd.read_csv(file_path_133_clean)
# df_137_clean = pd.read_csv(file_path_137_clean)
# df_142_clean = pd.read_csv(file_path_142_clean)
# df_150_clean = pd.read_csv(file_path_150_clean)
# df_131_meal = pd.read_csv(file_path_131_meal)
# df_147_meal = pd.read_csv(file_path_147_meal)
# df_107_work = pd.read_csv(file_path_107_work)
# df_150_work = pd.read_csv(file_path_109_work)
# df_d = pd.read_csv(file_path)

# # show
# df_d.head()

# %%
# import the necessary libraries and functions
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(os.getcwd())
# Out:
# /Users/petrospolydorou/thesis/Documents/projectaria_sandbox/projectaria_tools/projects/AriaDigitalTwinDatasetTools/object_anticipation/adt

# %%
# define the filepath
file_path = os.path.join('data', 'results', 'llm_predictions_results.csv')

# prints
print(file_path)

# load the dataframe
df_d = pd.read_csv(file_path)

# show
df_d.head()
# Out:
# data/results/llm_predictions_results.csv
#                               sequence  time  dot_value  distance_value  \
# 0  Apartment_release_work_seq107_M1292     2        0.7             1.5
# 1  Apartment_release_work_seq107_M1292     2        0.7             1.5
# 2  Apartment_release_work_seq107_M1292     2        0.7             1.5
# 3  Apartment_release_work_seq107_M1292     2        0.7             1.5
# 4  Apartment_release_work_seq107_M1292     2        0.7             1.5
#
#    dot_counts  distance_counts  model_overall_accuracy  precision  recall  \
# 0          15               15                   0.188      0.188   0.500
# 1          15               30                   0.188      0.188   0.500
# 2          15               45                   0.059      0.062   0.167
# 3          15               60                   0.133      0.143   0.333
# 4          15               75                   0.071      0.077   0.167
#
# ...

# %%
# the parameters that I have 
print("Below are the unique combinations of the parameters")

# prints 
print(f"The unique values of the dot counts are:",      df_d['sequence'].unique())
print(f"The unique values of the dot counts are:",      df_d['dot_counts'].unique())
print(f"The unique values of the distance counts are:", df_d['distance_counts'].unique())
print(f"The unique values of the dot values are:",      df_d['dot_value'].unique())
print(f"The unique values of the distance values are:", df_d['distance_value'].unique())
print(f"the unique values of the time are:",            df_d['time'].unique())
# Out:
# Below are the unique combinations of the parameters
# The unique values of the dot counts are: ['Apartment_release_work_seq107_M1292'
#  'Apartment_release_work_seq109_M1292'
#  'Apartment_release_meal_seq131_M1292'
#  'Apartment_release_meal_seq147_M1292'
#  'Apartment_release_clean_seq133_M1292'
#  'Apartment_release_clean_seq137_M1292'
#  'Apartment_release_clean_seq142_M1292'
#  'Apartment_release_clean_seq150_M1292']
# The unique values of the dot counts are: [15 30 45 60 75 90]
# The unique values of the distance counts are: [15 30 45 60 75 90]
# The unique values of the dot values are: [0.7 0.8 0.9]
# The unique values of the distance values are: [1.5 2.  2.5]
# the unique values of the time are: [2]

# %%
# the parameters that I have 
print("Below are the unique outcomes")
print('_')
print(f"The unique values of model accuarcy are:")
print(df_d['model_overall_accuracy'].unique())
print('_')
print(f"The unique values of precision are:", df_d['precision'].unique())
print('_')
print(f"The unique values of recall are:", df_d['recall'].unique())
print('_')
print(f"The unique values of llm activation sensitivity are:", df_d['llm_activation_sensitivity'].unique())
print('_')
print(f"the unique values of llm interaction accuracy are:", df_d['llm_interaction_accuracy'].unique())
print('_')
# Out:
# Below are the unique outcomes
# _
# The unique values of model accuarcy are:
# [0.188 0.059 0.133 0.071 0.083 0.2   0.062 0.143 0.077 0.154 0.1   0.167
#  0.091 0.182 0.    0.15  0.158 0.125 0.067 0.222 0.095 0.105 0.048 0.05
#  0.118 0.231 0.111 0.214 0.211 0.176 0.053 0.056 0.136 0.13  0.174 0.25
#  0.286 0.273 0.042 0.043 0.045 0.087 0.037 0.08  0.04  0.115 0.069 0.074
#  0.12  0.107 0.034 0.038 0.208 0.19  0.103 0.16  0.148 0.129 0.097 0.138
#  0.094 0.185 0.031 0.065 0.172 0.192 0.292 0.261 0.217 0.207 0.24  0.227
#  0.241 0.179 0.033 0.061 0.03  0.036 0.121 0.238 0.368 0.278 0.389 0.235
#  0.318 0.3   0.316 0.333 0.269 0.294 0.28  0.353 0.35  0.412 0.304 0.267
#  0.263]
# _
# The unique values of precision are: [0.188 0.062 0.143 0.077 0.091 0.2   0.067 0.167 0.083 0.111 0.1   0.
#  0.15  0.158 0.059 0.125 0.133 0.071 0.222 0.154 0.095 0.105 0.048 0.05
#  0.118 0.231 0.182 0.214 0.333 0.211 0.176 0.3   0.286 0.267 0.25  0.5
# ...

# %%
# Sequence - dataframes
sequence_dataframes_dict = {seq: df_d[df_d['sequence'] == seq].drop(df_d.columns[0], axis=1) for seq in df_d['sequence'].unique()}
sequence_dataframes_list = [df_d[df_d['sequence'] == seq].drop(df_d.columns[0], axis=1).reset_index() for seq in df_d['sequence'].unique()]
df_d = sequence_dataframes_dict['Apartment_release_clean_seq150_M1292']

# %%
# Assuming your DataFrame is named 'df'

# List of metrics for which you want to find the best parameter combinations
metrics = [
    'model_overall_accuracy', 
    'precision', 
    'recall', 
    'llm_activation_sensitivity', 
    'llm_interaction_accuracy'
]

# List of parameter columns
parameter_columns = ['time', 'dot_value', 'distance_value', 'dot_counts', 'distance_counts']

# For each metric, find the maximum value and the corresponding parameter combinations
# for metric in metrics:
#     max_value = df_d[metric].max()
#     best_rows = df_d[df_d[metric] == max_value]
#     print(f"Best combinations for '{metric}' (maximum value {max_value}):\n")
#     display_columns = parameter_columns + [metric]
#     display_df = best_rows[display_columns].reset_index(drop=True)
#     print(display_df)
#     print("\n" + "-"*80 + "\n")

best_combinations = {}

for metric in metrics:
    max_value = df_d[metric].max()
    best_rows = df_d[df_d[metric] == max_value]
    best_combinations[metric] = best_rows[parameter_columns + [metric]].reset_index(drop=True)

# Now, best_combinations is a dictionary where each key is a metric, and the value is a DataFrame.

print(best_combinations['precision'])
# Out:
#    time  dot_value  distance_value  dot_counts  distance_counts  precision
# 0     2        0.8             2.0          75               45      0.467
# 1     2        0.8             2.0          75               60      0.467
# 2     2        0.8             2.5          75               75      0.467
# 3     2        0.9             2.0          75               45      0.467

# %%
df_d.tail(324)
# Out:
#       time  dot_value  distance_value  dot_counts  distance_counts  \
# 2268     2        0.7             1.5          15               15
# 2269     2        0.7             1.5          15               30
# 2270     2        0.7             1.5          15               45
# 2271     2        0.7             1.5          15               60
# 2272     2        0.7             1.5          15               75
# ...    ...        ...             ...         ...              ...
# 2587     2        0.9             2.5          90               30
# 2588     2        0.9             2.5          90               45
# 2589     2        0.9             2.5          90               60
# 2590     2        0.9             2.5          90               75
# 2591     2        0.9             2.5          90               90
#
#       model_overall_accuracy  precision  recall  llm_activation_sensitivity  \
# 2268                   0.238      0.263   0.556                       0.368
# ...

# %% [markdown]
# also I want to then I want to somehow take of each compo dot_value [0.7, 0.8, 0.9] and for each distance_value[1.5, 2, 2.5] to have the best combinatio

# %%
# Define the varying parameters
high_dot_thresholds = [0.7, 0.8, 0.9]
distance_thresholds = [1.5, 2.0, 2.5]
high_dot_counters_threshold = [15, 30, 45, 60, 75, 90]
distance_counters_threshold = [15, 30, 45, 60, 75, 90]
# Out:
# Best combinations for sequence: Apartment_release_clean_seq150_M1292
#       time  dot_value  distance_value  dot_counts  distance_counts  \
# 2268   2.0        0.7             1.5        15.0             15.0
# 2269   2.0        0.7             1.5        15.0             30.0
# 2270   2.0        0.7             1.5        15.0             45.0
# 2271   2.0        0.7             1.5        15.0             60.0
# 2272   2.0        0.7             1.5        15.0             75.0
# ...    ...        ...             ...         ...              ...
# 2587   2.0        0.9             2.5        90.0             30.0
# 2588   2.0        0.9             2.5        90.0             45.0
# 2589   2.0        0.9             2.5        90.0             60.0
# 2590   2.0        0.9             2.5        90.0             75.0
# 2591   2.0        0.9             2.5        90.0             90.0
#
#       model_overall_accuracy  precision  recall  llm_activation_sensitivity  \
# ...

# %%
df_d.tail()
# Out:
#      time  dot_value  distance_value  dot_counts  distance_counts  \
# 319     2        0.9             2.5          90               30
# 320     2        0.9             2.5          90               45
# 321     2        0.9             2.5          90               60
# 322     2        0.9             2.5          90               75
# 323     2        0.9             2.5          90               90
#
#      model_overall_accuracy  precision  recall  llm_activation_sensitivity  \
# 319                   0.214      0.214   0.429                       0.500
# 320                   0.154      0.154   0.286                       0.538
# 321                   0.231      0.231   0.429                       0.538
# 322                   0.231      0.231   0.429                       0.538
# 323                   0.167      0.167   0.286                       0.545
#
#      llm_interaction_accuracy  Tp  Fp  Fp_out  Fp_in  Fn  Total_ground_truths  \
# ...

# %%
# the parameters that I have 
print("Below are the unique outcomes")
print('_')
print(f"The unique values of model accuarcy are:")
print(df_d['model_overall_accuracy'].unique())
print('_')
print(f"The unique values of precision are:", df_d['precision'].unique())
print('_')
print(f"The unique values of recall are:", df_d['recall'].unique())
print('_')
print(f"The unique values of llm activation sensitivity are:", df_d['llm_activation_sensitivity'].unique())
print('_')
print(f"the unique values of llm interaction accuracy are:", df_d['llm_interaction_accuracy'].unique())
print('_')
# Out:
# Below are the unique outcomes
# _
# The unique values of model accuarcy are:
# [0.263 0.412 0.188 0.133 0.077 0.278 0.25  0.312 0.438 0.125 0.267 0.2
#  0.143 0.083 0.35  0.333 0.353 0.062 0.3   0.286 0.316 0.375 0.167 0.118
#  0.192 0.292 0.231 0.208 0.217 0.304 0.227 0.158 0.4   0.214 0.091 0.261
#  0.389 0.238 0.467 0.071 0.235 0.24  0.211 0.368 0.111 0.176 0.308 0.294
#  0.    0.154 0.273 0.067 0.16  0.318]
# _
# The unique values of precision are: [0.263 0.412 0.188 0.2   0.143 0.091 0.278 0.25  0.312 0.438 0.133 0.267
#  0.214 0.154 0.1   0.35  0.333 0.353 0.067 0.3   0.286 0.316 0.375 0.167
#  0.118 0.192 0.292 0.231 0.208 0.217 0.304 0.227 0.158 0.125 0.4   0.182
#  0.111 0.261 0.389 0.238 0.467 0.077 0.235 0.083 0.24  0.211 0.368 0.176
#  0.308 0.294 0.    0.273 0.071 0.16  0.318]
# _
# The unique values of recall are: [0.714 1.    0.429 0.286 0.143 0.571 0.857 0.   ]
# _
# ...

# %% [markdown]
# # Line Plots of Performance Metrics vs. Parameter Values
#
# Model Overall Accuracy vs. dot_counts
#
# *Purpose*: Show how changing the dot_counts parameter affects the model_overall_accuracy.

# %%
# Line Plots of Performance Metrics vs. Parameter Values
sns.lineplot(data=df_d, x='dot_counts', y='model_overall_accuracy', marker='o')
plt.title('Model Accuracy vs. Dot Counts')
plt.xlabel('Dot Counts')
plt.ylabel('Model Overall Accuracy')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_counts',
    columns='distance_counts',
    values= 'llm_interaction_accuracy',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Accuracy Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %% [markdown]
# # Heatmap to Show Interactions Between Parameters and Performance
#
# Accuracy Heatmap with dot_counts and distance_counts
#
# *Purpose*: Visualize how combinations of dot_counts and distance_counts affect model_overall_accuracy.
#
# We are using Pivot table because it does not require unique combination.
#
# Otherwise Pivot needs to ensure that each combination of dot_value and distance_counts is unique.
#
# In our case, we have combinations of the same dot_value and distance counts with different model_accuracy_value so we don't have unique combinations.
#
# so we use pivot_table with aggregated function the mean

# %%
pivot_table = df_d.pivot_table(
    index='dot_value',
    columns='distance_counts',
    values='llm_interaction_accuracy',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Accuracy Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_value',
    columns='distance_counts',
    values='llm_interaction_accuracy',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Accuracy Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_value',
    columns='distance_counts',
    values='model_overall_accuracy',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Accuracy Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_value',
    columns='distance_counts',
    values='llm_activation_sensitivity',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('LLM Sensitivity Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_value',
    columns='distance_counts',
    values='recall',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Recall Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_value',
    columns='distance_value',
    values='precision',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Recall Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_counts',
    columns='distance_counts',
    values='precision',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Precision Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_counts',
    columns='distance_counts',
    values='recall',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Recall Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
pivot_table = df_d.pivot_table(
    index='dot_counts',
    columns='distance_counts',
    values='llm_activation_sensitivity',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('LLM Activation Sensitivy Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %%
df_d.head()
# Out:
#       time  dot_value  distance_value  dot_counts  distance_counts  \
# 2268     2        0.7             1.5          15               15
# 2269     2        0.7             1.5          15               30
# 2270     2        0.7             1.5          15               45
# 2271     2        0.7             1.5          15               60
# 2272     2        0.7             1.5          15               75
#
#       model_overall_accuracy  precision  recall  llm_activation_sensitivity  \
# 2268                   0.238      0.263   0.556                       0.368
# 2269                   0.368      0.412   0.778                       0.412
# 2270                   0.167      0.188   0.333                       0.438
# 2271                   0.188      0.200   0.375                       0.467
# 2272                   0.133      0.143   0.250                       0.500
#
#       llm_interaction_accuracy  Tp  Fp  Fp_out  Fp_in  Fn  \
# ...

# %%
pivot_table = df_d.pivot_table(
    index='dot_counts',
    columns='distance_counts',
    values='llm_interaction_accuracy',
    aggfunc='mean'  # or another aggregation function as needed
)

# Plot the heatmap
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('LLM Interaction Accuracy Heatmap')
plt.xlabel('Distance Counts')
plt.ylabel('Dot Value')
plt.show()

# %% [markdown]
# # Bar Charts for True Positives, False Positives, and False Negatives
#
# Grouped Bar Chart of Tp, Fp, and Fn vs. distance_counts
#
# *Purpose*: Highlight how the counts of true positives, false positives, and false negatives change with distance_counts.

# %%
# Verify column names
print(df_d.columns.tolist())

# Correct the melt function by using the correct id_vars
metrics = df_d[['dot_value', 'Tp', 'Fp', 'Fn']].melt(
    id_vars=['dot_value'],  # Use 'dot_value' if 'dot_counts' is not intended
    var_name='Metric',
    value_name='Count'
)

# Plot the bar chart
sns.barplot(data=metrics, x='dot_value', y='Count', hue='Metric')
plt.title('Tp, Fp, Fn by Dot Value')
plt.xlabel('Dot Value')
plt.ylabel('Count')
plt.show()
# Out:
# ['time', 'dot_value', 'distance_value', 'dot_counts', 'distance_counts', 'model_overall_accuracy', 'precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'Tp', 'Fp', 'Fp_out', 'Fp_in', 'Fn', 'Total_ground_truths', 'Total_llm_predictions', 'Total_llm_activations', 'Total_correspondances']

# %%
# Verify column names
print(df_d.columns.tolist())

# Correct the melt function by using the correct id_vars
metrics = df_d[['distance_value', 'Tp', 'Fp', 'Fn']].melt(
    id_vars=['distance_value'],  # Use 'dot_value' if 'dot_counts' is not intended
    var_name='Metric',
    value_name='Count'
)

# Plot the bar chart
sns.barplot(data=metrics, x='distance_value', y='Count', hue='Metric')
plt.title('Tp, Fp, Fn by Dot Value')
plt.xlabel('Distance Value')
plt.ylabel('Count')
plt.show()
# Out:
# ['time', 'dot_value', 'distance_value', 'dot_counts', 'distance_counts', 'model_overall_accuracy', 'precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'Tp', 'Fp', 'Fp_out', 'Fp_in', 'Fn', 'Total_ground_truths', 'Total_llm_predictions', 'Total_llm_activations', 'Total_correspondances']

# %%
# Verify column names
print(df_d.columns.tolist())

# Correct the melt function by using the correct id_vars
metrics = df_d[['dot_counts', 'Tp', 'Fp', 'Fn']].melt(
    id_vars=['dot_counts'],  # Use 'dot_value' if 'dot_counts' is not intended
    var_name='Metric',
    value_name='Count'
)

# Plot the bar chart
sns.barplot(data=metrics, x='dot_counts', y='Count', hue='Metric')
plt.title('Tp, Fp, Fn by Dot Value')
plt.xlabel('Dot Counts')
plt.ylabel('Count')
plt.show()
# Out:
# ['time', 'dot_value', 'distance_value', 'dot_counts', 'distance_counts', 'model_overall_accuracy', 'precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'Tp', 'Fp', 'Fp_out', 'Fp_in', 'Fn', 'Total_ground_truths', 'Total_llm_predictions', 'Total_llm_activations', 'Total_correspondances']

# %%
metrics = df_d[['distance_counts', 'Tp', 'Fp', 'Fn']].melt(
    id_vars=['distance_counts'],
    var_name='Metric',
    value_name='Count'
)

sns.barplot(data=metrics, x='distance_counts', y='Count', hue='Metric')
plt.title('Tp, Fp, Fn by Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Scatter Plot with Color Encoding
#
# Scatter Plot of dot_counts vs. distance_counts Colored by Accuracy
#
# *Purpose*: Identify parameter combinations that yield higher accuracy.

# %%
# Scatter Plots with Color Encoding
sns.scatterplot(data=df_d, x='dot_counts', y='distance_counts', hue='model_overall_accuracy', palette='viridis')
plt.title('Accuracy by Dot and Distance Values')
plt.show()

# %% [markdown]
# # Line Plot of LLM Activation Sensitivity and Interaction Accuracy
#
# Plot of llm_activation_sensitivity and llm_interaction_accuracy vs. distance_counts
#
# *Purpose*: Show how the model's sensitivity and interaction accuracy vary with distance_counts.

# %%
# Filter data for dot_value = 0.9 and dot_counts = 15
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 15)]

sns.lineplot(
    data=df_filtered,
    x='distance_counts',
    y='model_overall_accuracy',
    marker='o'
)
plt.title('Model Overall Accuracy vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Model Overall Accuracy')
plt.xticks(df_filtered['distance_counts'])
plt.show()

# %%
# Line Plots of Performance Metrics vs. Parameter Values
sns.lineplot(data=df_d, x='distance_counts', y='model_overall_accuracy', marker='o')
plt.title('Model Accuracy vs. distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Model Overall Accuracy')
plt.show()

# %%
# Line Plots of Performance Metrics vs. Parameter Values
sns.lineplot(data=df_d, x='dot_counts', y='model_overall_accuracy', marker='o')
plt.title('Model Accuracy vs. dot Counts')
plt.xlabel('Dot Counts')
plt.ylabel('Model Overall Accuracy')
plt.show()

# %%
# Filter data for dot_value = 0.9 and dot_counts = 15
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 30)]

sns.lineplot(
    data=df_filtered,
    x='distance_counts',
    y='model_overall_accuracy',
    marker='o'
)
plt.title('Model Overall Accuracy vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Model Overall Accuracy')
plt.xticks(df_filtered['distance_counts'])
plt.show()

# %%
# Filter data for dot_value = 0.9 and dot_counts = 15
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 45)]

sns.lineplot(
    data=df_filtered,
    x='distance_counts',
    y='model_overall_accuracy',
    marker='o'
)
plt.title('Model Overall Accuracy vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Model Overall Accuracy')
plt.xticks(df_filtered['distance_counts'])
plt.show()

# %%
# Filter data for dot_value = 0.9 and dot_counts = 15
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 60)]

sns.lineplot(
    data=df_filtered,
    x='distance_counts',
    y='model_overall_accuracy',
    marker='o'
)
plt.title('Model Overall Accuracy vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Model Overall Accuracy')
plt.xticks(df_filtered['distance_counts'])
plt.show()

# %%
# Filter data for dot_value = 0.9 and dot_counts = 15
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 75)]

metrics = df_filtered.melt(
    id_vars=['distance_counts'],
    value_vars=['precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'model_overall_accuracy'],
    var_name='Metric',
    value_name='Value'
)
sns.lineplot(
    data=metrics,
    x='distance_counts',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('Metrics vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Value')
plt.xticks(df_d['distance_counts'])
plt.show()

# %% [markdown]
# # Line Plots of Performance Metrics vs. Parameter Values
#
# b. Precision and Recall vs. distance_counts
#
# *Purpose*: Display how precision and recall vary with distance_counts.

# %%
metrics = df_filtered.melt(
    id_vars=['distance_value'],
    value_vars=['precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'model_overall_accuracy'],
    var_name='Metric',
    value_name='Value'
)
sns.lineplot(
    data=metrics,
    x='distance_value',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('Metrics vs. Distance Values')
plt.xlabel('Distance Values')
plt.ylabel('Value')
plt.xticks(df_filtered['distance_value'])
plt.show()

# %%
metrics = df_d.melt(
    id_vars=['dot_value'],
    value_vars=['precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'model_overall_accuracy'],
    var_name='Metric',
    value_name='Value'
)
sns.lineplot(
    data=metrics,
    x='dot_value',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('Metrics vs. Dot Values')
plt.xlabel('Dot Values')
plt.ylabel('Value')
plt.xticks(df_filtered['dot_value'])
plt.show()

# %%
df_d.head()
# Out:
#       time  dot_value  distance_value  dot_counts  distance_counts  \
# 2268     2        0.7             1.5          15               15
# 2269     2        0.7             1.5          15               30
# 2270     2        0.7             1.5          15               45
# 2271     2        0.7             1.5          15               60
# 2272     2        0.7             1.5          15               75
#
#       model_overall_accuracy  precision  recall  llm_activation_sensitivity  \
# 2268                   0.238      0.263   0.556                       0.368
# 2269                   0.368      0.412   0.778                       0.412
# 2270                   0.167      0.188   0.333                       0.438
# 2271                   0.188      0.200   0.375                       0.467
# 2272                   0.133      0.143   0.250                       0.500
#
#       llm_interaction_accuracy  Tp  Fp  Fp_out  Fp_in  Fn  \
# ...

# %%
metrics = df_d.melt(
    id_vars=['distance_counts'],
    value_vars=['precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'model_overall_accuracy'],
    var_name='Metric',
    value_name='Value'
)
sns.lineplot(
    data=metrics,
    x='distance_counts',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('Metrics vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Value')
plt.xticks(df_d['distance_counts'])
plt.show()

# %%
metrics = df_d.melt(
    id_vars=['dot_counts'],
    value_vars=['precision', 'recall', 'llm_activation_sensitivity', 'llm_interaction_accuracy', 'model_overall_accuracy'],
    var_name='Metric',
    value_name='Value'
)
sns.lineplot(
    data=metrics,
    x='dot_counts',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('Metrics vs. Dot Product Counts')
plt.xlabel('Dot Product Counts')
plt.ylabel('Value')
plt.xticks(df_d['dot_counts'])
plt.show()

# %% [markdown]
# # Line Plots of Performance Metrics vs. Parameter Values
#
# Model Overall Accuracy vs. dot_counts
#
# *Purpose*: Show how changing the dot_counts parameter affects the model_overall_accuracy.

# %%
# Line Plots of Performance Metrics vs. Parameter Values
sns.lineplot(data=df_d, x='dot_counts', y='model_overall_accuracy', marker='o')
plt.title('Model Accuracy vs. Dot Value')
plt.xlabel('Dot Value')
plt.ylabel('Model Overall Accuracy')
plt.show()

# %% [markdown]
# # Line Plots of Performance Metrics vs. Parameter Values
#
# Model Overall Accuracy vs. distance_counts
#
# *Purpose*: Show how changing the distance_counts parameter affects the model_overall_accuracy.

# %%
pivot_table = df_d.pivot_table(
    values='model_overall_accuracy',
    index='dot_counts',
    columns='distance_counts'
)
sns.heatmap(pivot_table, annot=True, fmt=".3f", cmap='YlGnBu')
plt.title('Model Overall Accuracy Heatmap')
plt.xlabel('Dot Counts')
plt.ylabel('Distance Counts')
plt.show()

# %% [markdown]
# # Scatter Plot with Color Encoding
#
# Scatter Plot of dot_counts vs. distance_counts Colored by Accuracy
#
# *Purpose*: Identify parameter combinations that yield higher accuracy.

# %%
sns.scatterplot(
    data=df_d,
    x='dot_counts',
    y='distance_counts',
    hue='model_overall_accuracy',
    size='model_overall_accuracy',
    palette='viridis',
    sizes=(50, 200),
    legend='brief'
)
plt.title('Accuracy by Dot Counts and Distance Counts')
plt.xlabel('Dot Counts')
plt.ylabel('Distance Counts')
plt.show()

# %% [markdown]
# # Grouped Bar Chart of Tp, Fp, and Fn vs. distance_counts
#
# **Purpose**: Highlight how the counts of true positives, false positives, and false negatives change with `dot_counts`.

# %%
metrics = df_filtered.melt(
    id_vars=['distance_counts'],
    value_vars=['Tp', 'Fp', 'Fn'],
    var_name='Metric',
    value_name='Count'
)
sns.barplot(
    data=metrics,
    x='distance_counts',
    y='Count',
    hue='Metric'
)
plt.title('Tp, Fp, Fn by Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Count')
plt.show()

# %%
metrics = df_d.melt(
    id_vars=['distance_counts'],
    value_vars=['Tp', 'Fp', 'Fn'],
    var_name='Metric',
    value_name='Count'
)
sns.barplot(
    data=metrics,
    x='distance_counts',
    y='Count',
    hue='Metric'
)
plt.title('Tp, Fp, Fn by Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Grouped Bar Chart of Tp, Fp, and Fn vs. distance_counts
#
# **Purpose**: Highlight how the counts of true positives, false positives, and false negatives change with `dot_counts`.

# %%
metrics = df_d.melt(
    id_vars=['dot_counts'],
    value_vars=['Tp', 'Fp', 'Fn'],
    var_name='Metric',
    value_name='Count'
)
sns.barplot(
    data=metrics,
    x='dot_counts',
    y='Count',
    hue='Metric'
)
plt.title('Tp, Fp, Fn by Dot Counts')
plt.xlabel('Dot Counts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Line Plot of LLM Activation Sensitivity and Interaction Accuracy
#
# Plot of llm_activation_sensitivity and llm_interaction_accuracy vs. distance_counts
#
# *Purpose*: Show how the model's sensitivity and interaction accuracy vary with distance_counts.

# %%
metrics = df_filtered.melt(
    id_vars=['distance_counts'],
    value_vars=['llm_activation_sensitivity', 'llm_interaction_accuracy'],
    var_name='Metric',
    value_name='Value'

)
sns.lineplot(
    data=metrics,
    x='distance_counts',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('LLM Sensitivity and Interaction Accuracy vs. Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Value')
plt.xticks(df_filtered['distance_counts'])
plt.show()

# %%
metrics = df_d.melt(
    id_vars=['distance_counts'],
    value_vars=['llm_activation_sensitivity', 'llm_interaction_accuracy'],
    var_name='Metric',
    value_name='Value'

)
sns.lineplot(
    data=metrics,
    x='distance_counts',
    y='Value',
    hue='Metric',
    marker='o'
)
plt.title('LLM Sensitivity and Interaction Accuracy vs. Distance Counts')m
plt.xlabel('Distance Counts')
plt.ylabel('Value')
plt.xticks(df_d['distance_counts'])
plt.show()
# Out:
#   Cell In[71], line 15
#     plt.title('LLM Sensitivity and Interaction Accuracy vs. Distance Counts')m
#                                                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # ROC Curve (Receiver Operating Characteristic Curve)
# *Purpose*: Illustrate the trade-off between true positive rate (sensitivity) and false positive rate.

# %%
# Filter the DataFrame and create an explicit copy
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 15)].copy()

# Calculate False Positive Rate (FPR) and True Positive Rate (TPR) using .loc
df_filtered.loc[:, 'FPR'] = df_filtered['Fp'] / (df_filtered['Fp'] + df_filtered['Tp'])
df_filtered.loc[:, 'TPR'] = df_filtered['Tp'] / (df_filtered['Tp'] + df_filtered['Fn'])

# Plot the ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(df_filtered['FPR'], df_filtered['TPR'], marker='o')
plt.title('ROC Curve for Dot Value = 0.9 and Dot Counts = 15')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.show()

# %%
## DIFFERENT WAY BUT SAME RESULT ## 

# Using assign to add new columns
df_filtered = df_d[(df_d['dot_value'] == 0.9) & (df_d['dot_counts'] == 15)].copy()

df_filtered = df_filtered.assign(
    FPR=lambda x: x['Fp'] / (x['Fp'] + x['Tp']),
    TPR=lambda x: x['Tp'] / (x['Tp'] + x['Fn'])
)

# Plot the ROC Curve
plt.plot(df_filtered['FPR'], df_filtered['TPR'], marker='o')
plt.title('ROC Curve for Dot Value = 0.9 and Dot Counts = 15')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.show()

# %%
# Calculate False Positive Rate (FPR) and True Positive Rate (TPR)
df_d['FPR'] = df_d['Fp'] / (df_d['Fp'] + df_d['Tp'])
df_d['TPR'] = df_d['Tp'] / (df_d['Tp'] + df_d['Fn'])

plt.plot(df_d['FPR'], df_d['TPR'], marker='o')
plt.title('ROC Curve for Dot Value = 0.9 and Dot Counts = 15')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %% [markdown]
# # Confusion Matrix Visualization
# Heatmap of Confusion Matrix Components for a Specific Setting

# %%
# Select the row corresponding to distance_counts = 60
cm_row = df_filtered[df_filtered['distance_counts'] == 60].iloc[0]

# Construct the confusion matrix
cm = pd.DataFrame({
    'Predicted Positive': [cm_row['Tp'], cm_row['Fp']],
    'Predicted Negative': [cm_row['Fn'], cm_row['Total_ground_truths'] - cm_row['Tp'] - cm_row['Fn']]
}, index=['Actual Positive', 'Actual Negative'])

sns.heatmap(cm, annot=True, cmap='Blues')
plt.title('Confusion Matrix at Distance Counts = 60')
plt.show()

# %%
# Select the row corresponding to distance_counts = 60
cm_row = df_d[df_d['distance_counts'] == 60].iloc[0]

# Construct the confusion matrix
cm = pd.DataFrame({
    'Predicted Positive': [cm_row['Tp'], cm_row['Fp']],
    'Predicted Negative': [cm_row['Fn'], cm_row['Total_ground_truths'] - cm_row['Tp'] - cm_row['Fn']]
}, index=['Actual Positive', 'Actual Negative'])

sns.heatmap(cm, annot=True, cmap='Blues')
plt.title('Confusion Matrix at Distance Counts = 60')
plt.show()

# %%
# Select the row corresponding to distance_counts = 60
cm_row = df_d.iloc[0]

# Construct the confusion matrix
cm = pd.DataFrame({
    'Predicted Positive': [cm_row['Tp'], cm_row['Fp']],
    'Predicted Negative': [cm_row['Fn'], cm_row['Total_ground_truths'] - cm_row['Tp'] - cm_row['Fn']]
}, index=['Actual Positive', 'Actual Negative'])

sns.heatmap(cm, annot=True, cmap='Blues')
plt.title('Confusion Matrix at Distance Counts = 60')
plt.show()

# %% [markdown]
# # Correlation Matrix
#
# Heatmap of Correlations Between Variables
#
# *Purpose*: Identify which parameters are most strongly associated with performance metrics.

# %%
# Assuming 'df' is your DataFrame
# Select relevant columns for correlation
correlation_cols = [
    'dot_counts', 'distance_counts',
    'model_overall_accuracy', 'precision', 'recall',
    'llm_activation_sensitivity', 'llm_interaction_accuracy',
    'Tp', 'Fp', 'Fn'
]

# Compute the correlation matrix
corr_matrix = df_d[correlation_cols].corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Generate a heatmap with annotations
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    linewidths=0.5,
    linecolor='white'
)

plt.title('Correlation Matrix of Key Variables')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Assuming 'df' is your DataFrame
# Select relevant columns for correlation
correlation_cols = [
    'dot_counts', 'distance_counts',
    'model_overall_accuracy', 'precision', 'recall',
    'llm_activation_sensitivity', 'llm_interaction_accuracy',
    'Tp', 'Fp', 'Fn'
]

# Compute the correlation matrix
corr_matrix = df_d[correlation_cols].corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Generate a heatmap with annotations
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    linewidths=0.5,
    linecolor='white'
)

plt.title('Correlation Matrix of Key Variables')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3D Surface Plot - 3D Plot of Model Accuracy Over dot_counts and distance_counts
#
# *Purpose*: Provide an intuitive visualization of how accuracy changes over a range of parameter values.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

X = df_d['dot_counts']
Y = df_d['distance_counts']
Z = df_d['model_overall_accuracy']

surf = ax.plot_trisurf(X, Y, Z, cmap=cm.viridis, edgecolor='none')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
ax.set_title('Model Accuracy Surface Plot')
ax.set_xlabel('Dot Counts')
ax.set_ylabel('Distance Counts')
ax.set_zlabel('Model Overall Accuracy')
plt.show()

# %% [markdown]
# # Histogram of Total LLM Predictions vs. Ground Truths
#
# *Purpose*: Compare the number of predictions made by the model against the ground truth to assess overfitting or underfitting.

# %% [markdown]
# df_filtered[['distance_counts', 'Total_llm_predictions', 'Total_ground_truths']].set_index('distance_counts').plot(kind='bar')
# plt.title('Total LLM Predictions vs. Ground Truths by Distance Counts')
# plt.xlabel('Distance Counts')
# plt.ylabel('Count')
# plt.xticks(rotation=0)
# plt.show()

# %%
df_filtered[['distance_counts', 'Total_llm_predictions', 'Total_ground_truths']].set_index('distance_counts').plot(kind='bar')
plt.title('Total LLM Predictions vs. Ground Truths by Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
df_d[['distance_counts', 'Total_llm_predictions', 'Total_ground_truths']].set_index('distance_counts').plot(kind='bar')
plt.title('Total LLM Predictions vs. Ground Truths by Distance Counts')
plt.xlabel('Distance Counts')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
df_d[['dot_counts', 'Total_llm_predictions', 'Total_ground_truths']].set_index('dot_counts').plot(kind='bar')
plt.title('Total LLM Predictions vs. Ground Truths by Dot Counts')
plt.xlabel('dot Counts')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Additional Visualization: LLM Activation Sensitivity vs. Interaction Accuracy
#
# *Purpose*: Analyze the relationship between LLM activation sensitivity and interaction accuracy.

# %%
sns.scatterplot(
    data=df_filtered,
    x='llm_activation_sensitivity',
    y='llm_interaction_accuracy',
    hue='distance_counts',
    palette='deep',
    marker='o',
    s=100
)
plt.title('LLM Activation Sensitivity vs. Interaction Accuracy')
plt.xlabel('LLM Activation Sensitivity')
plt.ylabel('LLM Interaction Accuracy')
plt.legend(title='Distance Counts')
plt.show()

# %%
sns.scatterplot(
    data=df_d,
    x='llm_activation_sensitivity',
    y='llm_interaction_accuracy',
    hue='distance_counts',
    palette='deep',
    marker='o',
    s=100
)
plt.title('LLM Activation Sensitivity vs. Interaction Accuracy')
plt.xlabel('LLM Activation Sensitivity')
plt.ylabel('LLM Interaction Accuracy')
plt.legend(title='Distance Counts')
plt.show()

# %%
filtered_df = df_d[(df_d['dot_counts'] == 45) & (df_d['distance_counts'] == 60)].copy()
filtered_df.head(10)
# Out:
#      time  dot_value  distance_value  dot_counts  distance_counts  \
# 15      2        0.7             1.5          45               60
# 51      2        0.7             2.0          45               60
# 87      2        0.7             2.5          45               60
# 123     2        0.8             1.5          45               60
# 159     2        0.8             2.0          45               60
# 195     2        0.8             2.5          45               60
# 231     2        0.9             1.5          45               60
# 267     2        0.9             2.0          45               60
# 303     2        0.9             2.5          45               60
#
#      model_overall_accuracy  precision  recall  llm_activation_sensitivity  \
# 15                    0.188      0.200   0.429                       0.400
# 51                    0.353      0.353   0.857                       0.412
# 87                    0.263      0.263   0.714                       0.368
# ...

# %%
sns.set(style="whitegrid")

# %%
# Pivot the data to create a matrix suitable for a heatmap
accuracy_pivot = filtered_df.pivot_table(index='dot_value', columns='distance_value', values='model_overall_accuracy', aggfunc = 'mean')

# Set up the matplotlib figure
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(accuracy_pivot, annot=True, fmt=".3f", cmap='YlGnBu')

# Add titles and labels
plt.title('Model Overall Accuracy Heatmap')
plt.xlabel('Distance Value')
plt.ylabel('Dot Value')

plt.show()

# %% [markdown]
# # Bar Plots for Precision and Recall
# *Purpose*: Compare precision and recall across different dot_value and distance_value combinations.

# %%
# Here is a measure of randomness # 

# Melt the DataFrame to long format for easier plotting
metrics_melted = filtered_df.melt(
    id_vars=['dot_value', 'distance_value'],
    value_vars=['precision', 'recall'],
    var_name='Metric',
    value_name='Value'
)

# Set up the matplotlib figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot Precision
sns.barplot(ax=axes[0], data=metrics_melted[metrics_melted['Metric'] == 'precision'],
            x='dot_value', y='Value', hue='distance_value', palette='viridis')
axes[0].set_title('Precision by Dot Value and Distance Value')
axes[0].set_xlabel('Dot Value')
axes[0].set_ylabel('Precision')

# Plot Recall
sns.barplot(ax=axes[1], data=metrics_melted[metrics_melted['Metric'] == 'recall'],
            x='dot_value', y='Value', hue='distance_value', palette='magma')
axes[1].set_title('Recall by Dot Value and Distance Value')
axes[1].set_xlabel('Dot Value')
axes[1].set_ylabel('Recall')

# Adjust legend
axes[0].legend(title='Distance Value')
axes[1].legend(title='Distance Value')

plt.tight_layout()
plt.show()

# %%
# Here is a measure of randomness # 

# Melt the DataFrame to long format for easier plotting
metrics_melted = df_d.melt(
    id_vars=['dot_value', 'distance_value'],
    value_vars=['precision', 'recall'],
    var_name='Metric',
    value_name='Value'
)

# Set up the matplotlib figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot Precision
sns.barplot(ax=axes[0], data=metrics_melted[metrics_melted['Metric'] == 'precision'],
            x='dot_value', y='Value', hue='distance_value', palette='viridis')
axes[0].set_title('Precision by Dot Value and Distance Value')
axes[0].set_xlabel('Dot Value')
axes[0].set_ylabel('Precision')

# Plot Recall
sns.barplot(ax=axes[1], data=metrics_melted[metrics_melted['Metric'] == 'recall'],
            x='dot_value', y='Value', hue='distance_value', palette='magma')
axes[1].set_title('Recall by Dot Value and Distance Value')
axes[1].set_xlabel('Dot Value')
axes[1].set_ylabel('Recall')

# Adjust legend
axes[0].legend(title='Distance Value')
axes[1].legend(title='Distance Value')

plt.tight_layout()
plt.show()

# %%
# Here is a measure of randomness # 

# Melt the DataFrame to long format for easier plotting
metrics_melted = df_d.melt(
    id_vars=['dot_value', 'distance_value'],
    value_vars=['llm_activation_sensitivity', 'llm_interaction_accuracy'],
    var_name='Metric',
    value_name='Value'
)

# Set up the matplotlib figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot Precision
sns.barplot(ax=axes[0], data=metrics_melted[metrics_melted['Metric'] == 'llm_activation_sensitivity'],
            x='dot_value', y='Value', hue='distance_value', palette='viridis')
axes[0].set_title('LLM Activation Sensitivity by Dot Value and Distance Value')
axes[0].set_xlabel('Dot Value')
axes[0].set_ylabel('Precision')

# Plot Recall
sns.barplot(ax=axes[1], data=metrics_melted[metrics_melted['Metric'] == 'llm_interaction_accuracy'],
            x='dot_value', y='Value', hue='distance_value', palette='magma')
axes[1].set_title('LLM Interaction Accuracy by Dot Value and Distance Value')
axes[1].set_xlabel('Dot Value')
axes[1].set_ylabel('Recall')

# Adjust legend
axes[0].legend(title='Distance Value')
axes[1].legend(title='Distance Value')

plt.tight_layout()
plt.show()

# %%
# Here is a measure of randomness # 

# Melt the DataFrame to long format for easier plotting
metrics_melted = df_d.melt(
    id_vars=['dot_counts', 'distance_counts'],
    value_vars=['llm_activation_sensitivity', 'llm_interaction_accuracy'],
    var_name='Metric',
    value_name='Value'
)

# Set up the matplotlib figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot Precision
sns.barplot(ax=axes[0], data=metrics_melted[metrics_melted['Metric'] == 'llm_activation_sensitivity'],
            x='dot_counts', y='Value', hue='distance_counts', palette='viridis')
axes[0].set_title('LLM Activation Sensitivity by Dot Counts and Distance Counts')
axes[0].set_xlabel('Dot Counts')
axes[0].set_ylabel('LLM Activation Sensitivity')

# Plot Recall
sns.barplot(ax=axes[1], data=metrics_melted[metrics_melted['Metric'] == 'llm_interaction_accuracy'],
            x='dot_counts', y='Value', hue='distance_counts', palette='magma')
axes[1].set_title('LLM Interaction Accuracy by Dot Value and Distance Value')
axes[1].set_xlabel('Dot Counts')
axes[1].set_ylabel('LLM Interaction Accuracy')

# Adjust legend
axes[0].legend(title='Distance Counts')
axes[1].legend(title='Distance Counts')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_d, 
                x='llm_activation_sensitivity', 
                y='llm_interaction_accuracy', 
                hue='dot_value', 
                style='distance_value',
                s=100, palette='deep')

plt.title('LLM Activation Sensitivity vs. LLM Interaction Accuracy')
plt.xlabel('LLM Activation Sensitivity')
plt.ylabel('LLM Interaction Accuracy')
plt.legend(title='Dot Value / Distance Value', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scatter Plot of LLMA Activation Sensitivity vs. LLM Interaction Accuracy
#
# *Purpose*: Explore the relationship between llm_activation_sensitivity and llm_interaction_accuracy across different dot_value and distance_value combinations.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=filtered_df, 
                x='llm_activation_sensitivity', 
                y='llm_interaction_accuracy', 
                hue='dot_value', 
                style='distance_value',
                s=100, palette='deep')

plt.title('LLM Activation Sensitivity vs. LLM Interaction Accuracy')
plt.xlabel('LLM Activation Sensitivity')
plt.ylabel('LLM Interaction Accuracy')
plt.legend(title='Dot Value / Distance Value', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar Chart of True Positives (Tp), False Positives (Fp), and False Negatives (Fn)
#
# *Purpose*: Compare the counts of Tp, Fp, and Fn across different dot_value and distance_value combinations.

# %%
# Melt the DataFrame for bar plotting
metrics_bar = filtered_df.melt(
    id_vars=['dot_value', 'distance_value'],
    value_vars=['Tp', 'Fp', 'Fn'],
    var_name='Metric',
    value_name='Count'
)

plt.figure(figsize=(12, 6))
sns.barplot(data=metrics_bar, 
            x='dot_value', 
            y='Count', 
            hue='Metric', 
            ci=None, 
            palette='Set2')

plt.title('True Positives, False Positives, and False Negatives by Dot Value')
plt.xlabel('Dot Value')
plt.ylabel('Count')
plt.legend(title='Metric')
plt.show()
# Out:
# /var/folders/8g/2f9_9wq551dbt5z3p_fg2khc0000gn/T/ipykernel_4268/2435828860.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=metrics_bar,

# %% [markdown]
# # Correlation Heatmap of Metrics
#
# *Purpose*: Understand the interrelationships between different performance metrics.

# %%
# Select relevant metrics for correlation
metrics = ['model_overall_accuracy', 'precision', 'recall', 
           'llm_activation_sensitivity', 'llm_interaction_accuracy', 
           'Tp', 'Fp', 'Fn']

# Compute the correlation matrix
corr_matrix = filtered_df[metrics].corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr_matrix, annot=True, cmap=cmap, fmt=".2f", linewidths=.5)

plt.title('Correlation Heatmap of Performance Metrics')
plt.show()

# %% [markdown]
# # Pair Plot of Metrics
#
# *Purpose*: Visualize pairwise relationships between different metrics, facilitating the identification of trends and correlations.

# %%
# Select relevant metrics
metrics = ['model_overall_accuracy', 'precision', 'recall', 
           'llm_activation_sensitivity', 'llm_interaction_accuracy']

# Create a pair plot
sns.pairplot(filtered_df, vars=metrics, hue='dot_value', markers=["o", "s", "D"], palette='bright')

plt.suptitle('Pair Plot of Performance Metrics', y=1.02)
plt.show()

# %% [markdown]
# # Box Plot of Metrics by Dot Value
#
# *Purpose*: Compare the distribution of various metrics across different dot_value categories.

# %%
# Melt the DataFrame for box plotting
metrics_box = filtered_df.melt(
    id_vars=['dot_value'],
    value_vars=['model_overall_accuracy', 'precision', 'recall', 
                'llm_activation_sensitivity', 'llm_interaction_accuracy'],
    var_name='Metric',
    value_name='Value'
)

plt.figure(figsize=(10, 6))
sns.boxplot(data=metrics_box, x='dot_value', y='Value', hue='Metric')
plt.title('Distribution of Performance Metrics by Dot Value')
plt.xlabel('Dot Value')
plt.ylabel('Metric Value')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Box Plot of Metrics by Distance Value
#
# *Purpose*: Compare the distribution of various metrics across different dot_value categories.

# %%
# Melt the DataFrame for box plotting
metrics_box = filtered_df.melt(
    id_vars=['distance_value'],
    value_vars=['model_overall_accuracy', 'precision', 'recall', 
                'llm_activation_sensitivity', 'llm_interaction_accuracy'],
    var_name='Metric',
    value_name='Value'
)

plt.figure(figsize=(10, 6))
sns.boxplot(data=metrics_box, x='distance_value', y='Value', hue='Metric')
plt.title('Distribution of Performance Metrics by Distance Value')
plt.xlabel('Distance Value')
plt.ylabel('Metric Value')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
